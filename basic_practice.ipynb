# %%
input("Making Python")
# Out:
# ''

# %%
user_age=input("What is your age")      #we can write integer or string it will execute

# %%
print(user_age)

# %%
a=input("Enter a number")
b=input("Enter a number")
print(a+b)      #input always return a value as string

# %%
print(type(a))      #we can see the type of the variable or label
# Out:
# <class 'str'>

# %%
a=input("Enter a numbet")       
b=input("Enter a numbet")
a=int(a)            #we can change input as integer value
b=int(b)
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 3
#       1 a=input("Enter a numbet")
#       2 b=input("Enter a numbet")
# ----> 3 a=int(a)            #we can change input as integer value
#       4 b=int(b)
#       5 print(a+b)
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# f-strings

# %%
name = "Deepthi"
age = 25
marks = 880
print(f"Student:{name}|Age:{age}|Marks:{marks}")    
print(f"Hello my name is {name}, Iam {age} years old and I got{marks}.")
# Out:
# Student:Deepthi|Age:25|Marks:880
# Hello my name is Deepthi, Iam 25 years old and I got880.

# %%
item = "coffee"
price = 20
gst = 0.18
total = price + gst
print(f"Deat customer your item is {item}, That item price is {price}, your total amount is {total}")
# Out:
# Deat customer your item is coffee, That item price is 20, your total amount is 20.18

# %% [markdown]
# FUNCTIONS

# %%
def function_name(x,y):
    print("Hello Deepthi")
    print(x+y)

# %%
function_name(1,20)
# Out:
# Hello Deepthi
# 21

# %%
def function_name(x,y):
    print(f"Hello Deepthi Your Value:, {result}")
    return(x+y)                                     #using return

# %%
result = function_name(1,22)
print(result)
# Out:
# Hello Deepthi Your Value:, 23
# 23

# %%
def multiplication(a,b):
    return(a%b)
result = multiplication(4,2)
print(result)
# Out:
# 0

# %%
def introduce(name, age, city):
    print(f"Hi, Iam {name}!")
    print(f"Iam {age} years old, from {city}")

# %%
introduce("Diana", 25, "Andra")
# Out:
# Hi, Iam Diana!
# Iam 25 years old, from Andra

# %%
def greet(name):
    print(f"Hello, {name}")

# %%
greet("Ashok")
greet("Deepthi")
# Out:
# Hello, Ashok
# Hello, Deepthi

# %%
#KEY ARGUMENTS
introduce(name = "Deepthi", city = "Hyd", age = 25)
# Out:
# Hi, Iam Deepthi!
# Iam 25 years old, from Hyd

# %%
def create_profile(name, age, city="Unknown"):  #parameters of the default values always in the last
    print(f"{name}, {age}, {city}!")

# %%
create_profile("Deepu", 23)#if we mention only 2 arguements it will nevel show error by default captured
# Out:
# Deepu, 23, Unknown!

# %%
bill_amount = 1000
gst = 0.18
discount = 25/100 * bill_amount
print(f"Discount: {discount}, YOU SAVED {discount}")
total_amount = bill_amount + gst + discount
print(total_amount)
# Out:
# Discount: 250.0, YOU SAVED 250.0
# 1250.1799999999998

# %%
price = 2500
def bill_amount(price, gst=0.18, discount=0):
    total = price + gst + discount
    print(total)

# %%
bill_amount(2500)
# Out:
# 2500.18

# %%
def shoping_bill(price):
    if price>3000:
        print("YOU GOT 25% OF DISCOUNT")
    else:
        print("ADD SOME ITEMS TO GET DISCOUNT")

# %%
shoping_bill(3400)
# Out:
# YOU GOT 25% OF DISCOUNT

# %%
def student(marks):
    if marks > 85:
        print("GRADE : A")
    elif marks > 75:
        print("GRADE : B")
    elif marks > 50:
        print("GRADE : C")
    elif marks > 35:
        print("GRADE : D")
    else:
        print("FAIL")

# %%
student(63)
# Out:
# GRADE : C

# %% [markdown]
# Python have some operators

# %% [markdown]
# Relation between a two operands and return a boolean as true or false

# %%
print(2==2)
print(2!=2)
print(2>2)
print(2<2)
print(2>=2)
print(2<=2)
print(True==1)  #True always take as 1
print(False==0) #False always take as 0
# Out:
# True
# False
# False
# False
# True
# True
# True
# True

# %%
#Boolean data types are a subset of int type True = 1, False = 0
#The comparision between two strings is always based on the ascii codes of each character.
#ASCII--Every character in a string internally converted to a standard integer to be stored in the memory.
#ASCII codes are standard in all languages. a to z is started from 97 and end 122
# A to Z starts from 65 and end 90.
# 1 to 9 ASCII codes (48 - 57)
# ASCII stands for (American Standard Code for Information Interchange)

# %%
print(ord("a"))
print(ord("z"))         #Finding ASCII values
print(ord("A"))
print(ord("Z"))
print(ord("0"))
print(ord("9"))
# Out:
# 97
# 122
# 65
# 90
# 48
# 57

# %%
print("Deepthi"=="Deepthi") #internally it is comparing with ASCII values
print("Deepthi"=="deepthi") #Capitals and smalls have seperate ASCII values so it is False
print("a"<="A") #here a = 97,A = 65
print("abd"<"abc")      #abd = 97 98 100,  abc = 97 98 99
# Out:
# True
# False
# False
# False

# %% [markdown]
# LOGICAL OPERATORS

# %%
# Binary operators or two {AND, OR}
# Unary operator is {NOT}
# Truly: All other than Falsy values are truly ex: 1,2,3,..., "abc", " " - inside space
#   Falsy: None, 0, 0.0, "", False
print("Deepthi" and 13)#the first operand is true so the result is depend on the second operand so output 13
print(13 and "Deepthi")#the first operand is true so the result is depend on the second operand so output Deepthi
print(" " and True)
print("Deepthi" or 13)#the first operand is true then the out put is first operad
print(False or "Deepthi")#the first operand is false then the out put is second operad
# Out:
# 13
# Deepthi
# True
# Deepthi
# Deepthi

# %% [markdown]
# CONDITIONAL STATEMENTS: if, ifelse/elif, else

# %%
i=input("Enter a number")
i=int(i)
if i%2==0:
    print("It is Even Number")
else:                                   #else statement always be write after if or after elif
    print("It is Odd Number")           #if is true executed other wise elif executed both are false else executed
# Out:
# It is Even Number

# %%
gender = input("Enter gender")
if gender == "m":
    print("Male")
elif gender == "f":
    print("Female")
else:
    print("Other")          # if and elif not executed else definatly executed
# Out:
# Other

# %%
is_student=input("ARE YOU STUDENT")
age=input("Enter your age")
age=int(age)
if (is_student=="yes" and age<25) or (age>=55):
    print("YOUR ELIGIBLE FOR THE DISCOUNT")
else:
 print("YOUR NOT ELIGIBLE FOR THE DISCOUNT")
# Out:
# YOUR NOT ELIGIBLE FOR THE DISCOUNT

# %%
correct_otp = 2622
for attempt in range(1,4):
    user_input = input(f"Attempt{attempt}: Enter OTP:")
    if user_input == correct_otp:
        print("OTP verified. Login Successfull!")
    else:
        print("Incorrect OTP. Try again.")
else:
    print("Maximum attempts reached, Account locked.")
# Out:
# Incorrect OTP. Try again.
# Incorrect OTP. Try again.
# Incorrect OTP. Try again.
# Maximum attempts reached, Account locked.

# %% [markdown]
# LOOPS:  Loops can be used to execute a block of code repetively they are {while loop, for loop}

# %%
#while loop: it is executed repeatedly untill the statement is false syntax: while condition:

i=20
while i>10:
    print(i)
    i=i-5
# Out:
# 20
# 15

# %%
#for loop: it follows range function {start, stop, step}
for variable in range(0,5,1):
    print(variable)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
number = 5
print(f"multiplication table of {number}")
for i in range(1,11):
    result = number*i
    print(f"{number}*{i}={result}")
# Out:
# multiplication table of 5
# 5*1=5
# 5*2=10
# 5*3=15
# 5*4=20
# 5*5=25
# 5*6=30
# 5*7=35
# 5*8=40
# 5*9=45
# 5*10=50

# %% [markdown]
# Indentation, break, continue, pass

# %%
correct_password = 123
Password = input("Enter password")
while Password != correct_password:
    print("Incorrect Password Please Try Again")
    break
if Password == correct_password:
    print("Login Successfully")

# %%
balance = 1000
while balance > 0:
    print(f"current balance: {balance}")
    amount = int(input("Enter withdrawal amount (0 to quit):"))
    if amount == 0:
        print("Thank you! Good Bye")
        break                           #break is used to stop the loop
    elif amount > balance:
        print("Insufficient balance!")
    else:
        balance = balance - amount
        print(f"{amount} withdraw successfully.")
# Out:
# current balance: 1000
# 1000 withdraw successfully.

# %%
for i in range(2):
    for j in range(3):
        print(i,j)
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2

# %%
for i in range(1,6):
    print("*" * i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
orders = [150,345,34,23,57,89]
for i in orders:
    if i < 0:               #indentetion is very important in every program it means space of next line
        continue            #better to use tab for the space
    print(i)
# Out:
# 150
# 345
# 34
# 23
# 57
# 89

# %%
orders = [150,345,34,23,0,89]
for i in orders:
    if i < 30:               
        continue            #it is skip the value of 23 and continue to next iteration
    print(i)
# Out:
# 150
# 345
# 34
# 89

# %%
for i in range(10):
                  
print("Deepthi is a good girl")
# Out:
#   Cell In[30], line 3
#     print("Deepthi is a good girl")
#     ^
# IndentationError: expected an indented block after 'for' statement on line 1

# %%
for i in range(10):
        pass          #instead of leaving a line use pass it is not shown any error and we can write afterwords
print("Deepthi is a good girl")
# Out:
# Deepthi is a good girl
